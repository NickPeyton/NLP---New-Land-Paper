# %% [markdown]
# # Embedding Test

# %% [markdown]
# #### Imports

# %%
import os
import shutil
import re
import ast
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
tqdm.pandas()
import json
from google import genai
import time
import nltk
import typing_extensions as typing
import platform
import matplotlib.pyplot as plt
import cv2
import torch
if platform.node() == 'Nick_Laptop':
    drive = 'C'
elif platform.node() == 'MSI':
    drive = 'D'
else:
    drive = 'uhhhhhh'
    print('Uhhhhhhhhhhhhh')
os.chdir(f'{drive}:/PhD/DissolutionProgramming/LND---Land-Paper')

#%% Configurating my little Gemini

PROCESSED = 'Data/Processed'
RAW = 'Data/Raw'
SURNAMES = f'{PROCESSED}/surname_info'
IMAGES = 'Output/Images'
TABLES = 'Output/Tables'
client = genai.Client(api_key='AIzaSyBfl8mrxUCsSHpOV8ToJWL9Po8fH0fshJY')

# %% [markdown]
# #### Loading

# %%
with open(f'{SURNAMES}/combined_surnames.json', 'r') as f:
    combined_surnames = json.load(f)

# %%
tester_list = [x for x in combined_surnames if len(x) > 5]
new_list = []
for list in tester_list[:3]:
    new_list += list

print(new_list)
new_list = ['Jelys', 'Giles', 'Ghillis', 'Jelys', 'Gilles', 'Gyles', 'Jelys']

result = client.models.embed_content(
    model='text-embedding-004',
    contents = new_list,
)
# Out:
# ['Abbis', 'Abba', 'Abbe', 'Abbie', 'Abb', 'Abbiss', 'Abbess', 'Abbay', 'Abby', 'Abbey', 'Abbs', 'Labey', 'Abethell', 'Bythell', 'Bithel', 'Bethell', 'Bethel', 'Bithell', 'Abrams', 'Abram', 'Abraham', 'Adburgham', 'Abraham', 'Abraham']

# %%
embedding_tensors = [torch.tensor(embed.values) for embed in result.embeddings]
for i, tensor in enumerate(embedding_tensors):

    if i == 0:
        continue
    print(new_list[i-1], new_list[i], 
          torch.cosine_similarity(embedding_tensors[i-1], tensor, dim=0).item())
# Out:
# Jelys Giles 0.5127607583999634
# Giles Ghillis 0.6674813032150269
# Ghillis Jelys 0.5054786801338196
# Jelys Gilles 0.48729532957077026
# Gilles Gyles 0.732048749923706
# Gyles Jelys 0.5930368304252625
